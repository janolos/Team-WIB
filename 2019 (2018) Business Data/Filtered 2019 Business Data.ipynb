# %% [markdown]
# # Load Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # Import Data

# %%
B2019=pd.read_csv(r"C:\Users\nbroo\OneDrive\Documents\Data Science Final Group Project\Women In Business Before And After The Pandemic\2019 (2018) Census Business Data.csv")
B2019.head()
# Out:
# C:\Users\nbroo\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (1,4,5,7,8,9,10,12,14,16,22) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#       GEO_ID      GEO_ID_F                  NAME        NAICS2017  \
# 0         id  Geo Footnote  Geographic Area Name  2017 NAICS code
# 1  0100000US           NaN         United States                0
# 2  0100000US           NaN         United States                0
# 3  0100000US           NaN         United States                0
# 4  0100000US           NaN         United States                0
#
#            NAICS2017_F        INDLEVEL        NAICS2017_LABEL        INDGROUP  \
# 0  2017 NAICS Footnote  Industry level  Meaning of NAICS code  Industry group
# 1                  NaN               2  Total for all sectors             NaN
# ...

# %% [markdown]
# # Clean & Subset Datasets

# %% [markdown]
# ## Drop Unwanted Columns From Datasets

# %%
B2019.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48738 entries, 0 to 48737
# Data columns (total 39 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   GEO_ID            48738 non-null  object
#  1   GEO_ID_F          1 non-null      object
#  2   NAME              48738 non-null  object
#  3   NAICS2017         48738 non-null  object
#  4   NAICS2017_F       8641 non-null   object
#  5   INDLEVEL          48738 non-null  object
#  6   NAICS2017_LABEL   48738 non-null  object
#  7   INDGROUP          1 non-null      object
#  8   SECTOR            48738 non-null  object
#  9   SUBSECTOR         1 non-null      object
#  10  SEX               48738 non-null  object
#  11  SEX_LABEL         48738 non-null  object
#  12  ETH_GROUP         48738 non-null  object
#  13  ETH_GROUP_LABEL   48738 non-null  object
#  14  RACE_GROUP        48738 non-null  object
#  15  RACE_GROUP_LABEL  48738 non-null  object
# ...

# %%
B2019.drop(['GEO_ID', 'GEO_ID_F', 'NAME', 'INDLEVEL', 'NAICS2017_F', 'NAICS2017_LABEL', 'INDGROUP', 'SECTOR', 'SUBSECTOR', 'SEX_LABEL', 'ETH_GROUP','ETH_GROUP_LABEL', 'RACE_GROUP','RACE_GROUP_LABEL', 'VET_GROUP','VET_GROUP_LABEL', 'QDESC', 'QDESC_LABEL', 'BUSCHAR', 'BUSCHAR_LABEL', 'YEAR', 'FIRMPDEMP', 'FIRMPDEMP_PCT', 'RCPPDEMP_PCT','EMP', 'EMP_PCT', 'PAYANN', 'PAYANN_PCT', 'FIRMPDEMP_S', 'FIRMPDEMP_PCT_S', 'RCPPDEMP_S', 'RCPPDEMP_PCT_S', 'EMP_S', 'EMP_PCT_S', 'PAYANN_S', 'PAYANN_PCT_S'], axis = 1, inplace = True)
B2019.head()
# Out:
#          NAICS2017       SEX  \
# 0  2017 NAICS code  Sex code
# 1                0         1
# 2                0         1
# 3                0         1
# 4                0         1
#
#                                             RCPPDEMP
# 0  Sales, value of shipments, or revenue of emplo...
# 1                                        38405539368
# 2                                         2270021185
# 3                                         2462681905
# 4                                          413777541

# %% [markdown]
# # Rename Columns

# %%
B2019R = B2019.rename(columns={'NAICS2017':'NAICS',
                                       'SEX':'Owners_Sex',
                                       'RCPPDEMP':'Sales'})

# %%
B2019R.head()
# Out:
#              NAICS Owners_Sex  \
# 0  2017 NAICS code   Sex code
# 1                0          1
# 2                0          1
# 3                0          1
# 4                0          1
#
#                                                Sales
# 0  Sales, value of shipments, or revenue of emplo...
# 1                                        38405539368
# 2                                         2270021185
# 3                                         2462681905
# 4                                          413777541

# %% [markdown]
# # Drop Unwanted Row

# %%
B2019_1 = B2019R.drop(labels=0, axis=0, index=None, columns=None)

# %%
B2019_1.head()
# Out:
#   NAICS Owners_Sex        Sales
# 1     0          1  38405539368
# 2     0          1   2270021185
# 3     0          1   2462681905
# 4     0          1    413777541
# 5     0          1   6023549720

# %% [markdown]
# # Convert datatype to integer

# %%
B2019_2 = B2019_1.apply(pd.to_numeric, errors='coerce')

# %%
B2019_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 48737 entries, 1 to 48737
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   NAICS       35043 non-null  float64
#  1   Owners_Sex  48737 non-null  int64
#  2   Sales       2925 non-null   float64
# dtypes: float64(2), int64(1)
# memory usage: 1.5 MB

# %% [markdown]
# # Drop NA/NAN Values

# %%
B2019_2.dropna()
# Out:
#       NAICS  Owners_Sex         Sales
# 1       0.0           1  3.840554e+10
# 2       0.0           1  2.270021e+09
# 3       0.0           1  2.462682e+09
# 4       0.0           1  4.137775e+08
# 5       0.0           1  6.023550e+09
# ...     ...         ...           ...
# 3907    0.0          98  2.404806e+10
# 3908    0.0          98  1.648210e+10
# 3909    0.0          98  1.284752e+08
# 3910    0.0          98  1.661057e+10
# 3911    0.0          98  1.738205e+08
#
# [2925 rows x 3 columns]

# %%
B2019_2.head()
# Out:
#    NAICS  Owners_Sex         Sales
# 1    0.0           1  3.840554e+10
# 2    0.0           1  2.270021e+09
# 3    0.0           1  2.462682e+09
# 4    0.0           1  4.137775e+08
# 5    0.0           1  6.023550e+09
