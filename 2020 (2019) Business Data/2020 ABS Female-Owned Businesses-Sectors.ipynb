# %%
import pandas as pd
import numpy as np

# %%
WB2020 = pd.read_csv('2020-2019 Census Business Data.csv')

# %%
WB2020.head()
# Out:
#       GEO_ID      GEO_ID_F                  NAME        NAICS2017  \
# 0         id  Geo Footnote  Geographic Area Name  2017 NAICS code
# 1  0100000US           NaN         United States               00
# 2  0100000US           NaN         United States               00
# 3  0100000US           NaN         United States               00
# 4  0100000US           NaN         United States               00
#
#            NAICS2017_F        NAICS2017_LABEL       SEX            SEX_LABEL  \
# 0  2017 NAICS Footnote  Meaning of NAICS code  Sex code  Meaning of Sex code
# 1                  NaN  Total for all sectors       001                Total
# 2                  NaN  Total for all sectors       001                Total
# 3                  NaN  Total for all sectors       001                Total
# 4                  NaN  Total for all sectors       001                Total
#
#         ETH_GROUP            ETH_GROUP_LABEL  ...  \
# 0  Ethnicity code  Meaning of Ethnicity code  ...
# ...

# %% [markdown]
# ## Rename Columns

# %%
WB2020_1 = WB2020.rename(columns={'NAICS2017':'NAICS',
                                       'SEX':'Owners_Sex',
                                       'ETH_GROUP': 'Owners_Ethnicity', 
                                       'RACE_GROUP':'Owners_Race', 
                                       'VET_GROUP':'Vet_Status', 
                                       'RCPPDEMP':'Sales', 
                                       'EMP': 'Employees', 
                                       'RCPPDEMP_S':'Sales_Std_Error', 
                                       'EMP_S':'Employees_Std_Error'})

# %% [markdown]
# ## Subset Dataset

# %%
WB2020_1.head()
# Out:
#       GEO_ID      GEO_ID_F                  NAME            NAICS  \
# 0         id  Geo Footnote  Geographic Area Name  2017 NAICS code
# 1  0100000US           NaN         United States               00
# 2  0100000US           NaN         United States               00
# 3  0100000US           NaN         United States               00
# 4  0100000US           NaN         United States               00
#
#            NAICS2017_F        NAICS2017_LABEL Owners_Sex            SEX_LABEL  \
# 0  2017 NAICS Footnote  Meaning of NAICS code   Sex code  Meaning of Sex code
# 1                  NaN  Total for all sectors        001                Total
# 2                  NaN  Total for all sectors        001                Total
# 3                  NaN  Total for all sectors        001                Total
# 4                  NaN  Total for all sectors        001                Total
#
#   Owners_Ethnicity            ETH_GROUP_LABEL  ...  \
# ...

# %%
WB2020_2 = WB2020_1[['NAICS', 
                     'Owners_Sex', 
                     'Owners_Ethnicity', 
                     'Owners_Race', 
                     'Vet_Status', 
                     'Sales', 
                     'Employees', 
                     'Sales_Std_Error', 
                     'Employees_Std_Error']]

# %%
WB2020_2.head()
# Out:
#              NAICS Owners_Sex Owners_Ethnicity Owners_Race    Vet_Status  \
# 0  2017 NAICS code   Sex code   Ethnicity code   Race code  Veteran code
# 1               00        001              001          00           001
# 2               00        001              001          00           001
# 3               00        001              001          00           001
# 4               00        001              001          00           001
#
#                                                Sales            Employees  \
# 0  Sales, value of shipments, or revenue of emplo...  Number of employees
# 1                                          298164421                    0
# 2                                         1266736429              5632339
# 3                                         1142368704              6329828
# 4                                         1440258482              8211284
#
#                                      Sales_Std_Error  \
# ...

# %% [markdown]
# ## Filter Dataframe to only contain female-owned businesses:

# %%
WB2020_F = WB2020_2.Owners_Sex.str.contains('002')
WB2020_2F = WB2020_2[WB2020_F]

# %%
WB2020_2F
# Out:
#       NAICS Owners_Sex Owners_Ethnicity Owners_Race Vet_Status      Sales  \
# 10       00        002              001          00        001   47463228
# 11       00        002              001          00        001  222730769
# 12       00        002              001          00        001  179280512
# 13       00        002              001          00        001  218176483
# 14       00        002              001          00        001  301700718
# ...     ...        ...              ...         ...        ...        ...
# 15216    99        002              001          00        004          R
# 15217    99        002              001          00        004          R
# 15218    99        002              001          00        004          S
# 15219    99        002              001          00        004          L
# 15220    99        002              001          00        004          D
#
#                   Employees Sales_Std_Error Employees_Std_Error
# ...

# %% [markdown]
# ## Determine which sectors were predominantly female-owned:

# %%
WB2020_2F.NAICS.value_counts()
# Out:
# 00            130
# 54            122
# 62            121
# 72            117
# 31-33         112
# 48-49(661)    110
# 56            110
# 23            104
# 44-45         103
# 81(663)       103
# 51            101
# 42             99
# 61             96
# 52(662)        95
# 71             95
# 53             87
# 55             81
# 11(660)        80
# 21             73
# 22             55
# 99             50
# Name: NAICS, dtype: int64

# %% [markdown]
# ### The following sectors were top 5 in 2020: (1) Professional/Scientific/Technical Services; (2) Health Care & Social Assistance; (3) Accomodation & Food Services; (4) Manufacturing; and (5) Transportation & Warehousing.
