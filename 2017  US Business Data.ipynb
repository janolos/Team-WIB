# %% [markdown]
# # load libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # load Data & View Data

# %%
WBiz2017 = pd.read_csv(r"C:\Users\ljones70\Desktop\WBiz2017.csv")
WBiz2017.head()
# Out:
#          INDLEVEL                  SECTOR        NAICS2017_LABEL       SEX  \
# 0  Industry level  NAICS economic sector   Meaning of NAICS code  Sex code
# 1               2                       0  Total for all sectors         1
# 2               2                       0  Total for all sectors         1
# 3               2                       0  Total for all sectors         1
# 4               2                       0  Total for all sectors         1
#
#              SEX_LABEL       ETH_GROUP            ETH_GROUP_LABEL RACE_GROUP  \
# 0  Meaning of Sex code  Ethnicity code  Meaning of Ethnicity code  Race code
# 1                Total               1                      Total          0
# 2                Total               1                      Total          0
# 3                Total               1                      Total          0
# 4                Total               1                      Total          0
#
# ...

# %% [markdown]
# # Rename Columns

# %%
WBiz2017.rename(columns={'SEX' : 'Owners Sex', 'ETH_GROUP' : 'Owners Ethnicity', 'RACE_GROUP' : 'Owners Race', 'VET_GROUP' : 'Owners Veteran Status', 'RCPPDEMP' : 'Sales', 'EMP' : 'Employees', 'RCPPDEMP_PCT_S' : 'Sales Std Error', 'EMP_S' : 'Employees Std Error'}, inplace=True)
WBiz2017.head()
# Out:
#          INDLEVEL                  SECTOR        NAICS2017_LABEL Owners Sex  \
# 0  Industry level  NAICS economic sector   Meaning of NAICS code   Sex code
# 1               2                       0  Total for all sectors          1
# 2               2                       0  Total for all sectors          1
# 3               2                       0  Total for all sectors          1
# 4               2                       0  Total for all sectors          1
#
#              SEX_LABEL Owners Ethnicity            ETH_GROUP_LABEL  \
# 0  Meaning of Sex code   Ethnicity code  Meaning of Ethnicity code
# 1                Total                1                      Total
# 2                Total                1                      Total
# 3                Total                1                      Total
# 4                Total                1                      Total
#
#   Owners Race      RACE_GROUP_LABEL                        EMPSZFI  ...  \
# ...

# %% [markdown]
# # Clean Dataset

# %%
WBiz2017 = WBiz2017.drop(labels=0, axis=0)
WBiz2017.head()
# Out:
#   INDLEVEL SECTOR        NAICS2017_LABEL Owners Sex SEX_LABEL  \
# 1        2      0  Total for all sectors          1     Total
# 2        2      0  Total for all sectors          1     Total
# 3        2      0  Total for all sectors          1     Total
# 4        2      0  Total for all sectors          1     Total
# 5        2      0  Total for all sectors          1     Total
#
#   Owners Ethnicity ETH_GROUP_LABEL Owners Race RACE_GROUP_LABEL EMPSZFI  ...  \
# 1                1           Total           0            Total     611  ...
# 2                1           Total           0            Total     611  ...
# 3                1           Total           0            Total     611  ...
# 4                1           Total           0            Total     611  ...
# 5                1           Total           0            Total     611  ...
#
#      PAYANN PAYANN_PCT FIRMPDEMP_S FIRMPDEMP_PCT_S RCPPDEMP_S Sales Std Error  \
# ...

# %% [markdown]
# # About Data

# %%
WBiz2017 = WBiz2017.apply(pd.to_numeric, errors='coerce')
print(WBiz2017.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 31509 entries, 1 to 31509
# Data columns (total 31 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   INDLEVEL             31509 non-null  int64
#  1   SECTOR               31509 non-null  int64
#  2   NAICS2017_LABEL      0 non-null      float64
#  3   Owners Sex           31509 non-null  int64
#  4   SEX_LABEL            0 non-null      float64
#  5   Owners Ethnicity     31509 non-null  int64
#  6   ETH_GROUP_LABEL      0 non-null      float64
#  7   Owners Race          31509 non-null  int64
#  8   RACE_GROUP_LABEL     0 non-null      float64
#  9   EMPSZFI              31509 non-null  int64
#  10  EMPSZFI_LABEL        0 non-null      float64
#  11  QDESC                0 non-null      float64
#  12  QDESC_LABEL          0 non-null      float64
#  13  BUSCHAR              0 non-null      float64
#  14  BUSCHAR_LABEL        0 non-null      float64
# ...

# %% [markdown]
# # Subset Data

# %%
WBiz2017Sub = WBiz2017[['INDLEVEL','Owners Sex', 'Owners Ethnicity', 'Owners Race', 'Sales', 'Employees', 'Sales Std Error', 'Employees Std Error']]

# %%
WBiz2017Sub.head()
# Out:
#    INDLEVEL  Owners Sex  Owners Ethnicity  Owners Race        Sales  \
# 1         2           1                 1            0  246491573.0
# 2         2           1                 1            0   40293525.0
# 3         2           1                 1            0   26560582.0
# 4         2           1                 1            0    1703970.0
# 5         2           1                 1            0    5940237.0
#
#    Employees  Sales Std Error  Employees Std Error
# 1        0.0              NaN                  0.0
# 2        0.0             17.6                  0.0
# 3        0.0              1.6                  0.0
# 4        0.0              0.3                  0.0
# 5        0.0             12.8                  0.0

# %% [markdown]
# # About Subset Data

# %%
WBiz2017Sub.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 31509 entries, 1 to 31509
# Data columns (total 8 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   INDLEVEL             31509 non-null  int64
#  1   Owners Sex           31509 non-null  int64
#  2   Owners Ethnicity     31509 non-null  int64
#  3   Owners Race          31509 non-null  int64
#  4   Sales                28246 non-null  float64
#  5   Employees            28246 non-null  float64
#  6   Sales Std Error      22872 non-null  float64
#  7   Employees Std Error  28246 non-null  float64
# dtypes: float64(4), int64(4)
# memory usage: 2.2 MB

# %% [markdown]
# # Change from Object to Float

# %%
WBiz2017Sub = WBiz2017Sub.apply (pd.to_numeric, errors='coerce')

print(WBiz2017Sub.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 31509 entries, 1 to 31509
# Data columns (total 8 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   INDLEVEL             31509 non-null  int64
#  1   Owners Sex           31509 non-null  int64
#  2   Owners Ethnicity     31509 non-null  int64
#  3   Owners Race          31509 non-null  int64
#  4   Sales                28246 non-null  float64
#  5   Employees            28246 non-null  float64
#  6   Sales Std Error      22872 non-null  float64
#  7   Employees Std Error  28246 non-null  float64
# dtypes: float64(4), int64(4)
# memory usage: 2.2 MB
# None

# %% [markdown]
# # Use Chi-Squares to determine if Owners' Sex depends on Sales

# %%
from scipy import stats

# %% [markdown]
# # Subset For Relevant Data

# %%
WBiz2017Sub2 = WBiz2017Sub[['Owners Sex', 'Owners Ethnicity', 'Owners Race', 'Sales', 'Employees', 'Sales Std Error', 'Employees Std Error']]

# %%
WBiz2017Sub2.head()
# Out:
#    Owners Sex  Owners Ethnicity  Owners Race        Sales  Employees  \
# 1           1                 1            0  246491573.0        0.0
# 2           1                 1            0   40293525.0        0.0
# 3           1                 1            0   26560582.0        0.0
# 4           1                 1            0    1703970.0        0.0
# 5           1                 1            0    5940237.0        0.0
#
#    Sales Std Error  Employees Std Error
# 1              NaN                  0.0
# 2             17.6                  0.0
# 3              1.6                  0.0
# 4              0.3                  0.0
# 5             12.8                  0.0

# %%
WBiz2017Sub2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 31509 entries, 1 to 31509
# Data columns (total 7 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Owners Sex           31509 non-null  int64
#  1   Owners Ethnicity     31509 non-null  int64
#  2   Owners Race          31509 non-null  int64
#  3   Sales                28246 non-null  float64
#  4   Employees            28246 non-null  float64
#  5   Sales Std Error      22872 non-null  float64
#  6   Employees Std Error  28246 non-null  float64
# dtypes: float64(4), int64(3)
# memory usage: 1.9 MB

# %% [markdown]
# # Create a contingency table:

# %%
from scipy import stats

# %%
WB2017_crosstab = pd.crosstab(WBiz2017Sub2['Owners Sex'], WBiz2017Sub2['Sales'])

# %%
stats.chi2_contingency(WB2017_crosstab)
# Out:
# (138675.84521120499,
#  0.0,
#  114380,
#  array([[10.21426043,  0.72959003,  0.72959003, ...,  0.72959003,
#          12.40303052, 12.40303052],
#         [ 0.74644197,  0.05331728,  0.05331728, ...,  0.05331728,
#           0.90639383,  0.90639383],
#         [ 0.79600651,  0.05685761,  0.05685761, ...,  0.05685761,
#           0.96657934,  0.96657934],
#         [ 0.74148552,  0.05296325,  0.05296325, ...,  0.05296325,
#           0.90037527,  0.90037527],
#         [ 0.80889329,  0.05777809,  0.05777809, ...,  0.05777809,
#           0.98222757,  0.98222757],
#         [ 0.69291227,  0.04949373,  0.04949373, ...,  0.04949373,
#           0.84139347,  0.84139347]]))

# %%
#p-value < 0.05, therefore there is a significant relationship between owners_sex and the number of sales. The values in the array are more than 5 and therefore meet the assumption.

# %% [markdown]
# # Run a correlation matrix

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
WBiz2017Sub2.corr(method='pearson')
# Out:
#                      Owners Sex  Owners Ethnicity  Owners Race     Sales  \
# Owners Sex             1.000000          0.952471     0.516929  0.100682
# Owners Ethnicity       0.952471          1.000000     0.413318  0.094729
# Owners Race            0.516929          0.413318     1.000000  0.013733
# Sales                  0.100682          0.094729     0.013733  1.000000
# Employees              0.096257          0.092600     0.003665  0.971455
# Sales Std Error       -0.032026         -0.033432     0.021933 -0.011263
# Employees Std Error   -0.044404         -0.035304     0.027657 -0.116973
#
#                      Employees  Sales Std Error  Employees Std Error
# Owners Sex            0.096257        -0.032026            -0.044404
# Owners Ethnicity      0.092600        -0.033432            -0.035304
# Owners Race           0.003665         0.021933             0.027657
# Sales                 0.971455        -0.011263            -0.116973
# ...

# %%
sns.heatmap(WBiz2017Sub2.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %%
#Strong, positive correlations between owners_sex and owners_ethnicity

# %% [markdown]
# # Determine Dependent t-Test

# %%
from scipy import stats

# %% [markdown]
# # Test assumptions:

# %%
WBiz2017Sub2['Owners Sex'].hist()
# Out:
# <AxesSubplot:>

# %%
WBiz2017Sub2['Owners Ethnicity'].hist()
# Out:
# <AxesSubplot:>

# %%
WBiz2017Sub2['Sales'].hist()
# Out:
# <AxesSubplot:>

# %%
#Data is not normally distributed and therefore violates assumptions.
