# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
B2017=pd.read_csv(r"C:\Users\ljones70\Desktop\2017Data.csv")
B2017.head()
# Out:
#          INDLEVEL                  SECTOR        NAICS2017_LABEL       SEX  \
# 0  Industry level  NAICS economic sector   Meaning of NAICS code  Sex code
# 1               2                       0  Total for all sectors         1
# 2               2                       0  Total for all sectors         1
# 3               2                       0  Total for all sectors         1
# 4               2                       0  Total for all sectors         1
#
#              SEX_LABEL       ETH_GROUP            ETH_GROUP_LABEL RACE_GROUP  \
# 0  Meaning of Sex code  Ethnicity code  Meaning of Ethnicity code  Race code
# 1                Total               1                      Total          0
# 2                Total               1                      Total          0
# 3                Total               1                      Total          0
# 4                Total               1                      Total          0
#
# ...

# %% [markdown]
# # Clean & subset data

# %%
B2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31510 entries, 0 to 31509
# Data columns (total 31 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   INDLEVEL          31510 non-null  object
#  1   SECTOR            31510 non-null  object
#  2   NAICS2017_LABEL   31510 non-null  object
#  3   SEX               31510 non-null  object
#  4   SEX_LABEL         31510 non-null  object
#  5   ETH_GROUP         31510 non-null  object
#  6   ETH_GROUP_LABEL   31510 non-null  object
#  7   RACE_GROUP        31510 non-null  object
#  8   RACE_GROUP_LABEL  31510 non-null  object
#  9   EMPSZFI           31510 non-null  object
#  10  EMPSZFI_LABEL     31510 non-null  object
#  11  QDESC             31510 non-null  object
#  12  QDESC_LABEL       31510 non-null  object
#  13  BUSCHAR           31510 non-null  object
#  14  BUSCHAR_LABEL     31510 non-null  object
#  15  YEAR              31510 non-null  object
# ...

# %%
B2017.drop(['GEO_ID', 'GEO_ID_F', 'NAME', 'INDLEVEL', 'NAICS2017_LABEL', 'INDGROUP', 'SECTOR', 'SUBSECTOR',  'NAICS2017_F', 'SEX_LABEL', 'ETH_GROUP','ETH_GROUP_LABEL', 'RACE_GROUP','RACE_GROUP_LABEL', 'VET_GROUP','VET_GROUP_LABEL', 'EMPSZFI','EMPSZFI_LABEL', 'YEAR', 'FIRMPDEMP', 'EMP','PAYANN','FIRMPDEMP_S', 'RCPPDEMP_S', 'EMP_S', 'PAYANN_S'], axis = 1, inplace = True)
B2017.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-11-acd0585dafb7> in <module>
# ----> 1 B2017.drop(['GEO_ID', 'GEO_ID_F', 'NAME', 'INDLEVEL', 'NAICS2017_LABEL', 'INDGROUP', 'SECTOR', 'SUBSECTOR',  'NAICS2017_F', 'SEX_LABEL', 'ETH_GROUP','ETH_GROUP_LABEL', 'RACE_GROUP','RACE_GROUP_LABEL', 'VET_GROUP','VET_GROUP_LABEL', 'EMPSZFI','EMPSZFI_LABEL', 'YEAR', 'FIRMPDEMP', 'EMP','PAYANN','FIRMPDEMP_S', 'RCPPDEMP_S', 'EMP_S', 'PAYANN_S'], axis = 1, inplace = True)
#       2 B2017.head()
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4306                 weight  1.0     0.8
#    4307         """
# -> 4308         return super().drop(
#    4309             labels=labels,
#    4310             axis=axis,
#
# ...

# %% [markdown]
# # Rename columns

# %%
B2017R = B2017.rename(columns={'NAICS2017':'NAICS',
                                       'SEX':'Owners_Sex',
                                       'RCPPDEMP':'Sales'})

# %%
B2017R.head()
# Out:
#          INDLEVEL                  SECTOR        NAICS2017_LABEL Owners_Sex  \
# 0  Industry level  NAICS economic sector   Meaning of NAICS code   Sex code
# 1               2                       0  Total for all sectors          1
# 2               2                       0  Total for all sectors          1
# 3               2                       0  Total for all sectors          1
# 4               2                       0  Total for all sectors          1
#
#              SEX_LABEL       ETH_GROUP            ETH_GROUP_LABEL RACE_GROUP  \
# 0  Meaning of Sex code  Ethnicity code  Meaning of Ethnicity code  Race code
# 1                Total               1                      Total          0
# 2                Total               1                      Total          0
# 3                Total               1                      Total          0
# 4                Total               1                      Total          0
#
# ...

# %% [markdown]
# # Drop columns

# %%
B2017_1 = B2017R.drop(labels=0, axis=0, index=None, columns=None)

# %%
B2017_1.head()
# Out:
#   INDLEVEL SECTOR        NAICS2017_LABEL Owners_Sex SEX_LABEL ETH_GROUP  \
# 1        2      0  Total for all sectors          1     Total         1
# 2        2      0  Total for all sectors          1     Total         1
# 3        2      0  Total for all sectors          1     Total         1
# 4        2      0  Total for all sectors          1     Total         1
# 5        2      0  Total for all sectors          1     Total         1
#
#   ETH_GROUP_LABEL RACE_GROUP RACE_GROUP_LABEL EMPSZFI  ...    PAYANN  \
# 1           Total          0            Total     611  ...  32263065
# 2           Total          0            Total     611  ...   6574190
# 3           Total          0            Total     611  ...   2243534
# 4           Total          0            Total     611  ...     61295
# 5           Total          0            Total     611  ...     55877
#
#   PAYANN_PCT FIRMPDEMP_S FIRMPDEMP_PCT_S RCPPDEMP_S RCPPDEMP_PCT_S EMP_S  \
# ...

# %% [markdown]
# # Convert datatype to integer

# %%
B2017_2 = B2017_1.apply(pd.to_numeric, errors='coerce')

# %%
B2017_2.head()
# Out:
#    INDLEVEL  SECTOR  NAICS2017_LABEL  Owners_Sex  SEX_LABEL  ETH_GROUP  \
# 1         2       0              NaN           1        NaN          1
# 2         2       0              NaN           1        NaN          1
# 3         2       0              NaN           1        NaN          1
# 4         2       0              NaN           1        NaN          1
# 5         2       0              NaN           1        NaN          1
#
#    ETH_GROUP_LABEL  RACE_GROUP  RACE_GROUP_LABEL  EMPSZFI  ...      PAYANN  \
# 1              NaN           0               NaN      611  ...  32263065.0
# 2              NaN           0               NaN      611  ...   6574190.0
# 3              NaN           0               NaN      611  ...   2243534.0
# 4              NaN           0               NaN      611  ...     61295.0
# 5              NaN           0               NaN      611  ...     55877.0
#
#    PAYANN_PCT  FIRMPDEMP_S  FIRMPDEMP_PCT_S  RCPPDEMP_S  RCPPDEMP_PCT_S  \
# ...

# %% [markdown]
# # Drop NA/NAN Values

# %%
B2017_2.dropna()
# Out:
# Empty DataFrame
# Columns: [INDLEVEL, SECTOR, NAICS2017_LABEL, Owners_Sex, SEX_LABEL, ETH_GROUP, ETH_GROUP_LABEL, RACE_GROUP, RACE_GROUP_LABEL, EMPSZFI, EMPSZFI_LABEL, QDESC, QDESC_LABEL, BUSCHAR, BUSCHAR_LABEL, YEAR, FIRMPDEMP, Sales, RCPPDEMP_PCT, EMP, EMP_PCT, PAYANN, PAYANN_PCT, FIRMPDEMP_S, FIRMPDEMP_PCT_S, RCPPDEMP_S, RCPPDEMP_PCT_S, EMP_S, EMP_PCT_S, PAYANN_S, PAYANN_PCT_S]
# Index: []
#
# [0 rows x 31 columns]

# %%
B2017_2.head()
# Out:
#    INDLEVEL  SECTOR  NAICS2017_LABEL  Owners_Sex  SEX_LABEL  ETH_GROUP  \
# 1         2       0              NaN           1        NaN          1
# 2         2       0              NaN           1        NaN          1
# 3         2       0              NaN           1        NaN          1
# 4         2       0              NaN           1        NaN          1
# 5         2       0              NaN           1        NaN          1
#
#    ETH_GROUP_LABEL  RACE_GROUP  RACE_GROUP_LABEL  EMPSZFI  ...      PAYANN  \
# 1              NaN           0               NaN      611  ...  32263065.0
# 2              NaN           0               NaN      611  ...   6574190.0
# 3              NaN           0               NaN      611  ...   2243534.0
# 4              NaN           0               NaN      611  ...     61295.0
# 5              NaN           0               NaN      611  ...     55877.0
#
#    PAYANN_PCT  FIRMPDEMP_S  FIRMPDEMP_PCT_S  RCPPDEMP_S  RCPPDEMP_PCT_S  \
# ...

# %% [markdown]
# # Data After NA's removed

# %%
B2017_1.head()
# Out:
#   INDLEVEL SECTOR        NAICS2017_LABEL Owners_Sex SEX_LABEL ETH_GROUP  \
# 1        2      0  Total for all sectors          1     Total         1
# 2        2      0  Total for all sectors          1     Total         1
# 3        2      0  Total for all sectors          1     Total         1
# 4        2      0  Total for all sectors          1     Total         1
# 5        2      0  Total for all sectors          1     Total         1
#
#   ETH_GROUP_LABEL RACE_GROUP RACE_GROUP_LABEL EMPSZFI  ...    PAYANN  \
# 1           Total          0            Total     611  ...  32263065
# 2           Total          0            Total     611  ...   6574190
# 3           Total          0            Total     611  ...   2243534
# 4           Total          0            Total     611  ...     61295
# 5           Total          0            Total     611  ...     55877
#
#   PAYANN_PCT FIRMPDEMP_S FIRMPDEMP_PCT_S RCPPDEMP_S RCPPDEMP_PCT_S EMP_S  \
# ...

# %% [markdown]
# # About info updated

# %%
B2017_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 31509 entries, 1 to 31509
# Data columns (total 31 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   INDLEVEL          31509 non-null  object
#  1   SECTOR            31509 non-null  object
#  2   NAICS2017_LABEL   31509 non-null  object
#  3   Owners_Sex        31509 non-null  object
#  4   SEX_LABEL         31509 non-null  object
#  5   ETH_GROUP         31509 non-null  object
#  6   ETH_GROUP_LABEL   31509 non-null  object
#  7   RACE_GROUP        31509 non-null  object
#  8   RACE_GROUP_LABEL  31509 non-null  object
#  9   EMPSZFI           31509 non-null  object
#  10  EMPSZFI_LABEL     31509 non-null  object
#  11  QDESC             31509 non-null  object
#  12  QDESC_LABEL       31509 non-null  object
#  13  BUSCHAR           31509 non-null  object
#  14  BUSCHAR_LABEL     31509 non-null  object
#  15  YEAR              31509 non-null  object
# ...

# %% [markdown]
# # Did I do this right?

# %%
B2017R.head()
# Out:
#          INDLEVEL                  SECTOR        NAICS2017_LABEL Owners_Sex  \
# 0  Industry level  NAICS economic sector   Meaning of NAICS code   Sex code
# 1               2                       0  Total for all sectors          1
# 2               2                       0  Total for all sectors          1
# 3               2                       0  Total for all sectors          1
# 4               2                       0  Total for all sectors          1
#
#              SEX_LABEL       ETH_GROUP            ETH_GROUP_LABEL RACE_GROUP  \
# 0  Meaning of Sex code  Ethnicity code  Meaning of Ethnicity code  Race code
# 1                Total               1                      Total          0
# 2                Total               1                      Total          0
# 3                Total               1                      Total          0
# 4                Total               1                      Total          0
#
# ...

# %% [markdown]
# # About info updated

# %%
B2017R.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31510 entries, 0 to 31509
# Data columns (total 31 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   INDLEVEL          31510 non-null  object
#  1   SECTOR            31510 non-null  object
#  2   NAICS2017_LABEL   31510 non-null  object
#  3   Owners_Sex        31510 non-null  object
#  4   SEX_LABEL         31510 non-null  object
#  5   ETH_GROUP         31510 non-null  object
#  6   ETH_GROUP_LABEL   31510 non-null  object
#  7   RACE_GROUP        31510 non-null  object
#  8   RACE_GROUP_LABEL  31510 non-null  object
#  9   EMPSZFI           31510 non-null  object
#  10  EMPSZFI_LABEL     31510 non-null  object
#  11  QDESC             31510 non-null  object
#  12  QDESC_LABEL       31510 non-null  object
#  13  BUSCHAR           31510 non-null  object
#  14  BUSCHAR_LABEL     31510 non-null  object
#  15  YEAR              31510 non-null  object
# ...
