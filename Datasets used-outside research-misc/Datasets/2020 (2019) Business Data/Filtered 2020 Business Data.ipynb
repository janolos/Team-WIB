# %% [markdown]
# # Load Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # Import Data

# %%
B2020=pd.read_csv(r"C:\Users\nbroo\OneDrive\Documents\Data Science Final Group Project\Women In Business Before And After The Pandemic\2020 (2019) Census Business Data.csv")
B2020.head()
# Out:
#       GEO_ID      GEO_ID_F                  NAME        NAICS2017  \
# 0         id  Geo Footnote  Geographic Area Name  2017 NAICS code
# 1  0100000US           NaN         United States               00
# 2  0100000US           NaN         United States               00
# 3  0100000US           NaN         United States               00
# 4  0100000US           NaN         United States               00
#
#            NAICS2017_F        NAICS2017_LABEL       SEX            SEX_LABEL  \
# 0  2017 NAICS Footnote  Meaning of NAICS code  Sex code  Meaning of Sex code
# 1                  NaN  Total for all sectors       001                Total
# 2                  NaN  Total for all sectors       001                Total
# 3                  NaN  Total for all sectors       001                Total
# 4                  NaN  Total for all sectors       001                Total
#
#         ETH_GROUP            ETH_GROUP_LABEL  ...  \
# 0  Ethnicity code  Meaning of Ethnicity code  ...
# ...

# %% [markdown]
# # Clean & Subset Datasets

# %% [markdown]
# ## Drop Unwanted Columns From Datasets

# %%
B2020.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15312 entries, 0 to 15311
# Data columns (total 25 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   GEO_ID            15312 non-null  object
#  1   GEO_ID_F          1 non-null      object
#  2   NAME              15312 non-null  object
#  3   NAICS2017         15312 non-null  object
#  4   NAICS2017_F       2838 non-null   object
#  5   NAICS2017_LABEL   15312 non-null  object
#  6   SEX               15312 non-null  object
#  7   SEX_LABEL         15312 non-null  object
#  8   ETH_GROUP         15312 non-null  object
#  9   ETH_GROUP_LABEL   15312 non-null  object
#  10  RACE_GROUP        15312 non-null  object
#  11  RACE_GROUP_LABEL  15312 non-null  object
#  12  VET_GROUP         15312 non-null  object
#  13  VET_GROUP_LABEL   15312 non-null  object
#  14  EMPSZFI           15312 non-null  object
#  15  EMPSZFI_LABEL     15312 non-null  object
# ...

# %%
B2020.drop(['GEO_ID', 'GEO_ID_F', 'NAME', 'NAICS2017_F', 'NAICS2017_LABEL', 'SEX_LABEL', 'ETH_GROUP','ETH_GROUP_LABEL', 'RACE_GROUP','RACE_GROUP_LABEL', 'VET_GROUP','VET_GROUP_LABEL', 'EMPSZFI', 'EMPSZFI_LABEL','YEAR', 'FIRMPDEMP', 'EMP', 'PAYANN', 'FIRMPDEMP_S', 'RCPPDEMP_S', 'EMP_S', 'PAYANN_S'], axis = 1, inplace = True)
B2020.head()
# Out:
#          NAICS2017       SEX  \
# 0  2017 NAICS code  Sex code
# 1               00       001
# 2               00       001
# 3               00       001
# 4               00       001
#
#                                             RCPPDEMP
# 0  Sales, value of shipments, or revenue of emplo...
# 1                                          298164421
# 2                                         1266736429
# 3                                         1142368704
# 4                                         1440258482

# %% [markdown]
# # Rename Columns

# %%
B2020R = B2020.rename(columns={'NAICS2017':'NAICS',
                                       'SEX':'Owners_Sex',
                                       'RCPPDEMP':'Sales'})

# %%
B2020R.head()
# Out:
#              NAICS Owners_Sex  \
# 0  2017 NAICS code   Sex code
# 1               00        001
# 2               00        001
# 3               00        001
# 4               00        001
#
#                                                Sales
# 0  Sales, value of shipments, or revenue of emplo...
# 1                                          298164421
# 2                                         1266736429
# 3                                         1142368704
# 4                                         1440258482

# %% [markdown]
# # Drop Unwanted Row

# %%
B2020_1 = B2020R.drop(labels=0, axis=0, index=None, columns=None)

# %%
B2020_1.head()
# Out:
#   NAICS Owners_Sex       Sales
# 1    00        001   298164421
# 2    00        001  1266736429
# 3    00        001  1142368704
# 4    00        001  1440258482
# 5    00        001  2445916742

# %% [markdown]
# # Convert datatype to integer

# %%
B2020_2 = B2020_1.apply(pd.to_numeric, errors='coerce')

# %%
B2020_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 15311 entries, 1 to 15311
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   NAICS       10839 non-null  float64
#  1   Owners_Sex  15311 non-null  int64
#  2   Sales       769 non-null    float64
# dtypes: float64(2), int64(1)
# memory usage: 478.5 KB

# %% [markdown]
# # Drop NA/NAN Values

# %%
B2020_2.dropna()
# Out:
#      NAICS  Owners_Sex         Sales
# 1      0.0           1  2.981644e+08
# 2      0.0           1  1.266736e+09
# 3      0.0           1  1.142369e+09
# 4      0.0           1  1.440258e+09
# 5      0.0           1  2.445917e+09
# ..     ...         ...           ...
# 934    0.0          98  2.321773e+08
# 935    0.0          98  3.111698e+08
# 936    0.0          98  8.908502e+08
# 937    0.0          98  1.088012e+09
# 938    0.0          98  2.237054e+10
#
# [769 rows x 3 columns]

# %%
B2020_2.head()
# Out:
#    NAICS  Owners_Sex         Sales
# 1    0.0           1  2.981644e+08
# 2    0.0           1  1.266736e+09
# 3    0.0           1  1.142369e+09
# 4    0.0           1  1.440258e+09
# 5    0.0           1  2.445917e+09
