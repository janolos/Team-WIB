# %% [markdown]
# # Load Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # Import Data

# %%
B2018=pd.read_csv(r"C:\Users\nbroo\OneDrive\Documents\Data Science Final Group Project\Women In Business Before And After The Pandemic\2018 (2017) Census Business Data.csv")
B2018.head()
# Out:
#       GEO_ID      GEO_ID_F                  NAME        NAICS2017  \
# 0         id  Geo Footnote  Geographic Area Name  2017 NAICS code
# 1  0100000US           NaN         United States                0
# 2  0100000US           NaN         United States                0
# 3  0100000US           NaN         United States                0
# 4  0100000US           NaN         United States                0
#
#          NAICS2017_LABEL        INDLEVEL        INDGROUP  SUBSECTOR  \
# 0  Meaning of NAICS code  Industry level  Industry group  SUBSECTOR
# 1  Total for all sectors               2             NaN        NaN
# 2  Total for all sectors               2             NaN        NaN
# 3  Total for all sectors               2             NaN        NaN
# 4  Total for all sectors               2             NaN        NaN
#
#            NAICS2017_F                  SECTOR  ...  \
# 0  2017 NAICS Footnote  NAICS economic sector   ...
# ...

# %% [markdown]
# # Clean & Subset Datasets

# %% [markdown]
# ## Drop Unwanted Columns From Datasets

# %%
B2018.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26444 entries, 0 to 26443
# Data columns (total 29 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   GEO_ID            26444 non-null  object
#  1   GEO_ID_F          1 non-null      object
#  2   NAME              26444 non-null  object
#  3   NAICS2017         26444 non-null  object
#  4   NAICS2017_LABEL   26444 non-null  object
#  5   INDLEVEL          26444 non-null  object
#  6   INDGROUP          1 non-null      object
#  7   SUBSECTOR         1 non-null      object
#  8   NAICS2017_F       4831 non-null   object
#  9   SECTOR            26444 non-null  object
#  10  SEX               26444 non-null  object
#  11  SEX_LABEL         26444 non-null  object
#  12  ETH_GROUP         26444 non-null  object
#  13  ETH_GROUP_LABEL   26444 non-null  object
#  14  RACE_GROUP        26444 non-null  object
#  15  RACE_GROUP_LABEL  26444 non-null  object
# ...

# %%
B2018.drop(['GEO_ID', 'GEO_ID_F', 'NAME', 'INDLEVEL', 'NAICS2017_LABEL', 'INDGROUP', 'SECTOR', 'SUBSECTOR',  'NAICS2017_F', 'SEX_LABEL', 'ETH_GROUP','ETH_GROUP_LABEL', 'RACE_GROUP','RACE_GROUP_LABEL', 'VET_GROUP','VET_GROUP_LABEL', 'EMPSZFI','EMPSZFI_LABEL', 'YEAR', 'FIRMPDEMP', 'EMP','PAYANN','FIRMPDEMP_S', 'RCPPDEMP_S', 'EMP_S', 'PAYANN_S'], axis = 1, inplace = True)
B2018.head()
# Out:
#          NAICS2017       SEX  \
# 0  2017 NAICS code  Sex code
# 1                0         1
# 2                0         1
# 3                0         1
# 4                0         1
#
#                                             RCPPDEMP
# 0  Sales, value of shipments, or revenue of emplo...
# 1                                          246491573
# 2                                         1246892073
# 3                                         1227385543
# 4                                         1526806215

# %% [markdown]
# # Rename Columns

# %%
B2018R = B2018.rename(columns={'NAICS2017':'NAICS',
                                       'SEX':'Owners_Sex',
                                       'RCPPDEMP':'Sales'})

# %%
B2018R.head()
# Out:
#              NAICS Owners_Sex  \
# 0  2017 NAICS code   Sex code
# 1                0          1
# 2                0          1
# 3                0          1
# 4                0          1
#
#                                                Sales
# 0  Sales, value of shipments, or revenue of emplo...
# 1                                          246491573
# 2                                         1246892073
# 3                                         1227385543
# 4                                         1526806215

# %% [markdown]
# # Drop Unwanted Row

# %%
B2018_1 = B2018R.drop(labels=0, axis=0, index=None, columns=None)

# %%
B2018_1.head()
# Out:
#   NAICS Owners_Sex       Sales
# 1     0          1   246491573
# 2     0          1  1246892073
# 3     0          1  1227385543
# 4     0          1  1526806215
# 5     0          1  2360974988

# %% [markdown]
# # Convert datatype to integer

# %%
B2018_2 = B2018_1.apply(pd.to_numeric, errors='coerce')

# %%
B2018_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 26443 entries, 1 to 26443
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   NAICS       20715 non-null  float64
#  1   Owners_Sex  26443 non-null  int64
#  2   Sales       18303 non-null  float64
# dtypes: float64(2), int64(1)
# memory usage: 826.3 KB

# %% [markdown]
# # Drop NA/NAN Values

# %%
B2018_2.dropna()
# Out:
#        NAICS  Owners_Sex         Sales
# 1        0.0           1  2.464916e+08
# 2        0.0           1  1.246892e+09
# 3        0.0           1  1.227386e+09
# 4        0.0           1  1.526806e+09
# 5        0.0           1  2.360975e+09
# ...      ...         ...           ...
# 26436   99.0          96  0.000000e+00
# 26437   99.0          96  0.000000e+00
# 26438   99.0          98  0.000000e+00
# 26439   99.0          98  0.000000e+00
# 26440   99.0          98  0.000000e+00
#
# [14270 rows x 3 columns]

# %%
B2018_2.head()
# Out:
#    NAICS  Owners_Sex         Sales
# 1    0.0           1  2.464916e+08
# 2    0.0           1  1.246892e+09
# 3    0.0           1  1.227386e+09
# 4    0.0           1  1.526806e+09
# 5    0.0           1  2.360975e+09
